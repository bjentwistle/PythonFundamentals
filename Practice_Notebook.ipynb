# %% [markdown]
# <a href="https://colab.research.google.com/github/bjentwistle/PythonFundamentals/blob/main/Practice_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # For practice
#
# Use this notebook to practice writing the functions needed for the main project.
#
# Test them here and when they are fully working, and you are happy with them, you can copy the whole function into the team project worksheet (by sending the code to the person who is managing the main program.

# %%
# Run this code everytime you open this notebook, to get the data
import csv
import urllib.request

def get_data():
    url = 'https://raw.githubusercontent.com/futureCodersSE/python-fundamentals/main/air-pollutants-daily-mean.csv'
    response = urllib.request.urlopen(url)
    lines = [l.decode('utf-8') for l in response.readlines()]
    data = csv.reader(lines)
    line_count = 0
    records = []
    for row in data:
        if line_count == 0:
            pass
        elif line_count == 1:
            keys = row
        else:
            values = row
            new_record = {k:v for k,v in zip(keys,values)}
            records.append(new_record)
        line_count += 1
    return records

air_data = get_data()

# %%
print(air_data)
# Out:
# [{'Date': '13/12/2020', 'Nitric oxide': '2.61812', 'Nitrogen dioxide': '7.95612', 'PM10 particulate matter (Grav Equiv)': '10.991'}, {'Date': '14/12/2020', 'Nitric oxide': '11.08795', 'Nitrogen dioxide': '18.28142', 'PM10 particulate matter (Grav Equiv)': '16.828'}, {'Date': '15/12/2020', 'Nitric oxide': '14.15952', 'Nitrogen dioxide': '22.59076', 'PM10 particulate matter (Grav Equiv)': '18.479'}, {'Date': '16/12/2020', 'Nitric oxide': '2.93377', 'Nitrogen dioxide': '8.86761', 'PM10 particulate matter (Grav Equiv)': '15.379'}, {'Date': '17/12/2020', 'Nitric oxide': '13.24388', 'Nitrogen dioxide': '20.69463', 'PM10 particulate matter (Grav Equiv)': '16.047'}, {'Date': '18/12/2020', 'Nitric oxide': '5.4104', 'Nitrogen dioxide': '10.06412', 'PM10 particulate matter (Grav Equiv)': '15.822'}, {'Date': '19/12/2020', 'Nitric oxide': '6.05927', 'Nitrogen dioxide': '11.72574', 'PM10 particulate matter (Grav Equiv)': '15.218'}, {'Date': '20/12/2020', 'Nitric oxide': '6.01603', 'Nitrogen dioxid
# ...

# %% [markdown]
# **Use the code cell below to practice and to develop your functions for individual menu options**
#
# ---

# %%
def user_interface():
  #Ask the user to chose which data they want to see
  print("Please chose which data you would like to display")
  print("1. What problems does Nitric Oxide cause for humans and the environment")
  print("2. What problems does Nitrogen Dioxide cause for humans and the environment")
  print("3. What problems does PM10 particular matter cause for humans and the environment")
  print("4. List of Nitric Oxide levels each day")
  print("5. List of Nitrogen Oxide levels each day")
  print("6. List of PM10 particulate matter levels each day")
  print("7. Average daily level of Nitric Oxide for the year to December 2021")
  print("8. Average daily level of Nitrogen Dioxide for the year to December 2021")
  print("9. Average daily level of PM10 particulate matter for the year to December 2021")
  print("0 - Quit")

  user_input = int(input("Choose: ")) #user makes a choice of data to see.

  if user_input == 1: # if they chose option 1 display problems of Nitric Oxide
    #call funtion that Madga made
    print("test")

  if user_input == 2: # if they chose option 2 display problems of Nitrogen dioxide
    #call funtion that Madga made
    print("test")

  if user_input == 3: # if they chose option 3 display problems of PM10 particular matter
    #call funtion that Madga made
    print("test")

  if user_input == 4: # if they chose option 4 display list of daily Nitric Oxide levels 
    #call funtion that Chengjing made
    print("test")

  if user_input == 5: # if they chose option 5 display list of daily Nitrogen dioxide levels 
    #call funtion that Chengjing made
    print("test")

  if user_input == 6: # if they chose option 6 display list of daily PM10 particulate matter levels  
    #call funtion that Chengjing made
    print("test")

  if user_input == 7: # if they chose option 7 display list of yearly average of Nitric Oxide levels 
    #call funtion that Kufre made
    print("test")

  if user_input == 8: # if they chose option 8 display list of yearly average of Nitrogen dioxide levels
    #call funtion that Kufre made
    print("test")

  if user_input == 9: # if they chose option 9 display list of yearly average of PM10 particulate matter levels
    #call funtion that Kufre made 
    print("test")
  
  if user_input == 0: 
    quit()


  else:
    print("invalid choice")


user_interface()
